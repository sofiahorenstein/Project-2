# %%
import petapi

# %%
import json

# %%
pet_data = petapi.get_pets(5)

# %%
print(pet_data)
#pprint(pet_data)
# Out:
# [{'id': 46665249, 'organization_id': 'VA126', 'url': 'https://www.petfinder.com/cat/head-and-the-heart-fiv-46665249/va/richmond/richmond-animal-care-and-control-va126/?referrer_id=b61fa746-e5bd-4a6c-bb42-50ac1dec831f', 'type': 'Cat', 'species': 'Cat', 'breeds': {'primary': 'Domestic Short Hair', 'secondary': None, 'mixed': True, 'unknown': False}, 'colors': {'primary': None, 'secondary': None, 'tertiary': None}, 'age': 'Adult', 'gender': 'Male', 'size': 'Medium', 'coat': None, 'attributes': {'spayed_neutered': True, 'house_trained': False, 'declawed': False, 'special_needs': False, 'shots_current': False}, 'environment': {'children': None, 'dogs': None, 'cats': None}, 'tags': [], 'name': 'Head And The Heart | FIV+', 'description': 'Primary Color: Grey Tabby Weight: 13.8lbs Age: 6yrs 1mths 2wks Animal has been Neutered', 'photos': [], 'status': 'adoptable', 'status_changed_at': '2019-11-23T17:00:49+0000', 'published_at': '2019-11-23T17:00:49+0000', 'distance': None, 'contact': {'email
# ...

# %%
print(json.dumps(pet_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "_links": {
#             "organization": {
#                 "href": "/v2/organizations/va126"
#             },
#             "self": {
#                 "href": "/v2/animals/46665249"
#             },
#             "type": {
#                 "href": "/v2/types/cat"
#             }
#         },
#         "age": "Adult",
#         "attributes": {
#             "declawed": false,
#             "house_trained": false,
#             "shots_current": false,
#             "spayed_neutered": true,
#             "special_needs": false
#         },
#         "breeds": {
#             "mixed": true,
#             "primary": "Domestic Short Hair",
#             "secondary": null,
#             "unknown": false
#         },
#         "coat": null,
#         "colors": {
#             "primary": null,
#             "secondary": null,
#             "tertiary": null
#         },
#         "contact": {
#             "address": {
# ...

# %%
len(pet_data)
# Out:
# 80
